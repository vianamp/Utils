# %%
import os
import urllib
from PIL import Image
from apiclient.discovery import build

APIKeyFile = open('api_key.txt','r')

APIKeyFileContent = APIKeyFile.read().splitlines()

APIKeyFile.close()

APIdeveloperKey = APIKeyFileContent[0]

APIcx = APIKeyFileContent[1]

service = build("customsearch", "v1",developerKey=APIdeveloperKey)

curr_idx = 1

FileName = []

for query in range(10):
    
    res = service.cse().list(
        q='greek buildings',
        cx=APIcx,
        searchType='image',
        imgType='clipart',
        start=curr_idx,
        num=10,
    ).execute()

    for item in res['items']:
        try:
            urllib.urlretrieve(item["link"],os.path.basename(item['link']))
            print '[%03d] '%curr_idx + item['title']
            FileName.append(os.path.basename(item['link']))
        except:
            pass
        curr_idx = curr_idx + 1
# Out:
# [001] Ancient Greek Architecture Facts for Kids
# [002] Ancient Greek architecture - Wikipedia, the free encyclopedia
# [003] Greek Architecture | Essential Humanities
# [004] Ancient Greek architecture - Wikipedia, the free encyclopedia
# [005] Architecture in Greece: Periods and styles - Greeka.com
# [006] Early Greek Architecture
# [007] Greek Architecture - Crystalinks
# [008] Greek Architecture Pictures - Ancient Greece - HISTORY.com
# [009] Greek Architecture - Crystalinks
# [010] 25 Influential Pieces Of Ancient Greek Architecture
# [011] Greek Architecture | Essential Humanities
# [012] Ancient Greece on Pinterest | Ancient Greek Architecture ...
# [013] Introduction to Greek architecture | A beginner's guide to ancient ...
# [014] Architecture in Greece: Periods and styles - Greeka.com
# [015] Introduction to Greek architecture | A beginner's guide to ancient ...
# [016] Ancient Greek Architecture Facts for Kids
# [017] famous-ancient-greek- ...
# [018] 3rd Grade, Greek Architecture - Lessons - TES
# [019] Architecture: Ancient Greek Architecture In Athens Modern ...
# [020] Early Greek Architecture
# [022] 10 Must See Ancient Greek Temples | GreekReporter.com
# [023] Ancient Greek Architecture - Quatr.us
# [024] American Democracy is not Greek, but the Greeks were the founders ...
# [025] Greek Architecture - Ancient History Encyclopedia
# [026] Ancient Greek Building In Athens Stock Photography - Image: 4631702
# [027] Greek Architecture Pictures - Ancient Greece - HISTORY.com
# [028] famous-ancient-greek- ...
# [029] Caryatid - Wikipedia, the free encyclopedia
# [030] Greek Architecture Columns Design Inspiration 25363 Architecture ...
# [031] Famous Historic Buildings & Archaeological Site in Greece – Athens ...
# [032] Ancient Greek temple - Wikipedia, the free encyclopedia
# [033] Architectural Features in Ancient Greek Buildings | Action ...
# [034] 10 Must See Ancient Greek Temples | GreekReporter.com
# [035] Was Ancient Greece essentially a Middle Eastern civilization ...
# [036] Ancient Greek Architecture on Pinterest | Roman Architecture ...
# [037] Ancient Architecture And Early Greek Architecture 20 Image 19 of ...
# [038] Greek Architecture Drawings Inspiration 513335 Architecture Design ...
# [039] Greek Temples
# [040] Greek architecture - Conservapedia
# [041] Contemporary Greek Architecture | Pulalo Home
# [042] greek architecture post beam triangle - Google Search | 0 Greek ...
# [043] Architecture in ancient Greece
# [044] Ancient Greek Achievements - 7th Grade Social Studies with Wells ...
# [045] Greek Architecture and Decoration - Ancient Greece
# [046] Greek Revival | Louisiana Architecture – A Handbook On Styles
# [047] Greek Architecture Design Decorating 4114096 Architecture Design ...
# [048] greek | Photography Blog of Watcher Romano
# [049] Greek architecture Facts, information, pictures | Encyclopedia.com ...
# [050] Greek Architecture | HSTRY for Education
# [051] A Modest Proposal - Official site of Stephen Fry
# [052] greek architecture post beam triangle - Google Search | 0 Greek ...
# [053] 10 must see ancient greek temples – HeritageDaily – Heritage ...
# [054] Architecture and Building in Ancient Greece
# [055] Greek/Roman/Egyptian Architecture on Pinterest | Ancient Egyptian ...
# [056] Greek Temples
# [058] Ancient Greek Building In Athens Stock Photography - Image: 4631702
# [060] List of ancient Greek temples - Wikipedia, the free encyclopedia
# [062] ancient greek by jixiong | Publish with Glogster!
# [063] BBC Bitesize - What do we know about ancient Greek culture?
# [064] Romeo's Class Wiki - 1st hour 2011-2012 Greece
# [065] 5 Famous Ancient Greek Buildings - Beautiful Tourism
# [066] Ancient greek architecture - Estate, buildings information portal
# [067] Greek/Roman Architecture on Pinterest | Ancient Greek Architecture ...
# [068] Greek Architecture Temples Decorating 47167 Architecture Design ...
# [069] Ancient Greek Architecture 1906 Edwardian by SurrenderDorothy
# [070] Greek Building Graphics Vector Art & Graphics | freevector.com
# [071] Ancient Greek Buildings Stock Image - Image: 18554891
# [072] Architecture in Ancient Greece | Essay | Heilbrunn Timeline of Art ...
# [073] Ancient Greek Building In Athens - Free Stock Photos & Images ...
# [074] The Greek Revival in small town New England
# [075] Greek Architecture on Modern Buildings in the U.S. - Lesson.Website
# [076] 427/527 Greek Architecture | Department of the History of Art and ...
# [077] Houses & Buildings - Botley c.of.e Controlled primary schoolClass ...
# [078] Ancient Building With Greek Architecture Stock Photo, Picture And ...
# [079] Introduction to Fine Art-Study Guide, Chapter 2
# [080] Unique Greek Building - Gallery
# [081] Vector Ancient Greek Architecture Royalty Free Stock Image - Image ...
# [082] Modern Ancient Greek Temples And Ancient Greek Temple Ancient ...
# [083] The Influence of Ancient Greek Architecture (with Pictures)
# [084] Great Building With Greek Style - Free Stock Photos & Images ...
# [085] Ancient Greek temple - Wikipedia, the free encyclopedia
# [086] greek architecture project
# [087] Ancient Greek Architecture: Dorian, Ionic & Corinthian - Video ...
# [088] Greece | MS|Architecture
# [089] Panoramic View Of Ancient Greek Buildings On Sunny Day Stock Photo ...
# [090] Greek Revival
# [091] Temple of Hephaestus: Ancient Greek Mystery • Photo Vide
# [092] Greek City-states Buildings Related Keywords & Suggestions - Greek ...
# [093] Greek Revival Architecture in America
# [094] Architecture in Greece: Periods and styles - Greeka.com
# [095] Fibonacci Numbers and The Golden Section in Art, Architecture and ...
# [096] ArchitectureConnections: Architecture & History: My Big Fat Greek ...
# [097] 12 Gifts Ancient Greece Gave To The World
# [098] What is a Pediment? - Ancient Greek Architecture - Quatr.us
# [099] Ancient Greek Architecture: Dorian, Ionic & Corinthian - Video ...
# [100] the-parthenon-at-dusk-3 - Greek Architecture Pictures - Ancient ...

# %%
curr_idx = 1
os.mkdir('results')
for fname in FileName:
    try:
        im = Image.open(fname)
        im.convert('RGB').save('results/a%05d'%curr_idx+'.jpg')
        curr_idx = curr_idx + 1 
    except:
        pass
    try:
        os.remove(fname)
    except:
        pass
